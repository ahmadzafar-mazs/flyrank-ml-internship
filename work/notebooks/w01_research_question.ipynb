# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ahmadzafar-mazs/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# # 1. My lane (or freestyle) and why
#
# My lane is **CTR / Engagement Opportunity Scoring**. I chose this lane because the starter dataset contains useful signals such as impressions, clicks, CTR, average position, and engagement. I want to identify pages that may be under-performing relative to their visibility and prioritize which pages should be reviewed for metadata, content, or monitoring improvements. This lane is useful because it connects measurable search performance with a practical content decision.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# The decision is which visible pages should be prioritized for review based on their click and engagement performance. An SEO or content team could use the ranked results to decide which pages need metadata improvements, content updates, or closer monitoring. A wrong recommendation could waste the team's time and resources on pages that do not need improvement, while pages with a real opportunity could be missed.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/ahmadzafar-mazs/flyrank-ml-internship/main/data/raw/content_refresh_anonymized.csv"

df = pd.read_csv(url)

print("Dataset shape:", df.shape)

print("\nAll column names:")
print(df.columns.tolist())
# Out:
# Dataset shape: (30000, 44)
#
# All column names:
# ['content_id', 'client_id', 'search_volume', 'competition', 'competition_level', 'cpc', 'content_type', 'main_intent', 'word_count', 'char_count', 'provider_used', 'model_used', 'impressions_90d', 'clicks_90d', 'pageviews_90d', 'sessions_90d', 'users_90d', 'engaged_sessions_90d', 'ai_sessions_90d', 'scroll_events_90d', 'days_with_impressions', 'days_with_sessions', 'impressions_last_30d', 'clicks_last_30d', 'sessions_last_30d', 'impressions_prev_30d', 'clicks_prev_30d', 'sessions_prev_30d', 'content_age_days', 'age_tier', 'age_tier_order', 'days_since_last_update', 'freshness_tier', 'word_count_tier', 'char_count_tier', 'ctr', 'avg_position', 'engagement_rate', 'scroll_rate', 'ai_traffic_pct', 'impression_tier', 'position_tier', 'trend_direction', 'trend_pct']

# %%
print("Dataset shape:", df.shape)

print("\nQuick look at the data:")

print("Total impressions (90d):", df["impressions_90d"].sum())
print("Total clicks (90d):", df["clicks_90d"].sum())
print("Total engaged sessions (90d):", df["engaged_sessions_90d"].sum())
# Out:
# Dataset shape: (30000, 44)
#
# Quick look at the data:
# Total impressions (90d): 156010989
# Total clicks (90d): 482920
# Total engaged sessions (90d): 29758

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
#
# I can use the available search performance and engagement metrics to identify pages that appear to have stronger or weaker engagement opportunities. The analysis can support prioritization and monitoring decisions based on observed patterns in the data.
#
# I cannot claim that these relationships are causal or that the analysis proves why a page performs better or worse. The results should be treated as decision support, not as a guarantee that changing a page will improve its performance.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
